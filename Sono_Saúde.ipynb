# %% [markdown]
# <a href="https://colab.research.google.com/github/Roger-Quinelato/Sono-Sa-de/blob/main/Sono_Sa%C3%BAde.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Para o portifólio. Mexer nele dias 7, 8, 9, 10. Pelo menos 40/por dia

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# leitura do data.

# %%
sono = pd.read_csv('Sono-Saude.csv')
sono
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
sono_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
sono_df = pd.DataFrame(sono)
sono_df.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
sns.relplot(data= sono_df, x= 'Age', y= 'Sleep Duration', hue= 'Gender')
#Idade, Tempo dormindo e Genero.

# %%
sns.relplot(data= sono_df, x= 'Age', y= "Sleep Duration", hue= "Stress Level")

# %% [markdown]
# Com isso percebi que quem dorme menos é mais estressado independente da idade. Que 7 a partir de horas já tem muito menos estressados

# %%
sns.histplot(data= sono_df, x= 'Gender', y= 'Stress Level')
# Out:
# <Axes: xlabel='Gender', ylabel='Stress Level'>

# %%
sono_df['Occupation'] = sono_df['Occupation'].replace({'Software Engineer':'Soft. Eng.', 'Sales Representative': 'Sales Represen.'})

sono_df_mean = sono_df.groupby('Occupation')['Stress Level'].mean()

plt.hist(sono_df['Occupation'], bins= 20, color= 'blue',edgecolor='black')

plt.title("Profissão x Stress")
plt.xlabel("Occupation")
plt.ylabel("Stress Level")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# Não curti o histograma do sns

# %%
sono_df['Occupation'].value_counts()
# Out:
# Occupation
# Nurse              73
# Doctor             71
# Engineer           63
# Lawyer             47
# Teacher            40
# Accountant         37
# Salesperson        32
# Soft. Eng.          4
# Scientist           4
# Sales Represen.     2
# Manager             1
# Name: count, dtype: int64
